# %%
# -*- coding: utf-8 -*-
__author__ = 'NadyaMotina'

import time
import json
import codecs
import pandas
import operator
import community
import igraph
import networkx as nx
from gensim.models import Word2Vec
from itertools import combinations
from transliterate import translit
from scipy.stats.stats import pearsonr
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
start_time = time.time()
model = Word2Vec.load_word2vec_format('../../Models/ruscorpora.model.bin', binary=True)
print 'Model loaded successfully. It took ', time.time() - start_time, ' seconds'
# Out:
# Model loaded successfully. It took  10.5481779575  seconds

# %% [markdown]
# # networkx

# %%
def build_rng(word, model, topn=10, threshold=0):
    # 1) find N most similar words from the model
    # 2) for each combination of 2 words find if there is some other neighbor in between them
    #    * if there is no such word: add an edge
    # output: graph object
    wg = nx.Graph()
    neighbors = model.most_similar(word, topn=topn)
    neighbors.append((word, 1.0))
    for pair in combinations(neighbors, 2):
        word0 = pair[0][0]
        word1 = pair[1][0]
        similarity = model.similarity(word0, word1)
        if similarity > threshold:
            remaining = [vertex for vertex in neighbors if vertex != pair[0] \
                         and vertex != pair[1]]
            for vertex in remaining:
                drawedge = True
                candidate = vertex[0]
                if model.similarity(candidate, word1) > similarity \
                and model.similarity(candidate, word0) > similarity:
                    drawedge = False
                    break
                if drawedge == True:
                    # Cyrillic symbols cause error for graph plotting
                    # so we need to transliterate words
                    w1 = translit(pair[0][0], 'ru', reversed=True) 
                    w2 = translit(pair[1][0], 'ru', reversed=True)
                    wg.add_edge(w1, w2, weight=similarity)
    # remove the starting node to see only resulting clusters
    start = translit(word, 'ru', reversed=True)
    word_clustering = nx.clustering(wg, start)
    wg.remove_node(start)
    return wg, start, word_clustering
 
def draw_rng(wg):
    # draw high cosine similarity edges bold
    # and low cosine similarity edges faint and dashed
    # print nx.info(wg)    
    threshold = 0.45
    elarge=[(u,v) for (u,v,d) in wg.edges(data=True) if d['weight'] > threshold]
    esmall=[(u,v) for (u,v,d) in wg.edges(data=True) if d['weight'] <= threshold]
    plt.figure(figsize=(10,10))
    plt.axis('off')
    pos = nx.spring_layout(wg)
    partition = louvain_communities(wg)
    values = [partition.get(node) for node in wg.nodes()]
    nx.draw_networkx_nodes(wg, pos, node_size = 200, node_color = values)
    nx.draw_networkx_edges(wg, pos, edgelist=elarge, width=4, alpha=0.7, edge_color='g')
    nx.draw_networkx_edges(wg, pos, edgelist=esmall, width=4, alpha=0.2, edge_color='b', style='dashed')
    nx.draw_networkx_labels(wg, pos, font_size=16, font_family='sans-serif')
    plt.show()
    
def louvain_communities(graph):
    # Compute the partition of the graph nodes which maximises the modularity  
    # using the Louvain heuristices
    partition = community.best_partition(graph)
    for i in list(set(partition.values())):
        print i, '_________________________'
        for j in partition:
            if partition[j] == i:
                print translit(j, 'ru')
    return partition

# %%
# model can read only words with a POS-tag (S=noun, V=verb, A=adjective)

word = 'мир_S'.decode('utf8')
graph, node, word_clustering = build_rng(word, model, topn=35, threshold=0.1)
print nx.average_clustering(graph)
draw_rng(graph)

## save a graph for Gephi
# nx.write_graphml(graph, "test.graphml", encoding='utf-8')
# Out:
# 0.61616136157
# 0 _________________________
# недолга_С
# окружаюсчее_С
# облик_С
# видимостЬ_С
# сроднятЬ_В
# подлунная_С
# жизнЬ_С
# полнота_С
# махалЬ_С
# падкостЬ_С
# 1 _________________________
# планета_С
# вселенная_С
# космос_С
# мироздание_С
# премудростия_С
# 2 _________________________
# миропорядок_С
# бытие_С
# природа_С
# обЬемлюсчий_А
# творение_С
# действителЬностЬ_С
# стихия_С
# познаватЬ_В
# сусчностЬ_С
# реалЬностЬ_С
# сусчество_С
# тварный_А
# 3 _________________________
# цивилизация_С
# мироустройство_С
# царство_С
# страна_С
# россия_С
# тварЬ_С
# европа_С
# человечество_С

# %% [markdown]
# # igraph

# %%
def i_build_rng(word, model, topn=10, threshold=0):
    # 1) find N most similar words from the model
    # 2) for each combination of 2 words find if there is some other neighbor in between them
    #    * if there is no such word: add an edge
    # output: graph object
    wg = igraph.Graph()
    neighbors = model.most_similar(word, topn=topn)
    neighbors.append((word, 1.0))
    for pair in combinations(neighbors, 2):
        word0 = pair[0][0]
        word1 = pair[1][0]
        similarity = model.similarity(word0, word1)
        if similarity > threshold:
            remaining = [vertex for vertex in neighbors if vertex != pair[0] \
                         and vertex != pair[1]]
            for vertex in remaining:
                drawedge = True
                candidate = vertex[0]
                if model.similarity(candidate, word1) > similarity \
                and model.similarity(candidate, word0) > similarity:
                    drawedge = False
                    break
                if drawedge == True:
                    w1 = pair[0][0].encode('utf8') 
                    w2 = pair[1][0].encode('utf8') 
                    try: wg.vs.find(w1)
                    except: wg.add_vertices(w1)
                    try: wg.vs.find(w2)
                    except: wg.add_vertices(w2)
                    if wg.are_connected(w1, w2) is False:
                        wg.add_edge(w1, w2, weight=similarity)
    # remove the starting node to see only resulting clusters
    wg.delete_vertices(word.encode('utf8') )
    return wg, word.encode('utf8')

# %%
word = 'мир_S'.decode('utf8')
graph, node = i_build_rng(word, model, topn=30, threshold=0.5)
print graph.transitivity_undirected()
color_list = ['red','blue','green','cyan','pink','orange','grey','yellow','white','black','purple']
graph.vs["label"] = graph.vs["name"]
community = graph.community_leading_eigenvector(weights='weight')
print community
layout = graph.layout("kk")
# igraph.plot(graph, '../../graph.svg', bbox = (500,500), layout = layout, labels='label',\
#             vertex_color=[color_list[x] for x in community.membership], \
#            edge_width = [i*3 for i in graph.es['weight']])
# Out:
# 0.384615384615
# Clustering with 19 elements and 4 clusters
# [0] вселенная_S, мироздание_S, космос_S,
#     планета_S
# [1] человечество_S, россия_S, цивилизация_S,
#     страна_S, европа_S
# [2] реальность_S, действительность_S, бытие_S,
#     познавать_V, тварный_A
# [3] сущность_S, природа_S, существо_S, стихия_S,
#     тварь_S

# %% [markdown]
# ## Evaluation
# #### Step 1. collect the Gold Standard

# %%
infile = open("gold_standard.json", 'r')
GS = json.load(infile)
infile.close()

# %%
for i in range(30, 40):

    sample = GS.keys()[i]   #10
    print '"' + sample + '": ['
    for i in GS[sample]:
        print '\t"' + i + '"'
    print ']'
    print ''
# Out:
# "мужик": [
# 	"простолюдин, крестьянин"
# 	"- мужчина, человек мужского пола"
# 	"мужчина как носитель мужских качеств"
# 	"обращение мужчин друг к другу"
# 	"вообще невоспитанный, грубый, неотёсанный человек"
# 	"Русский|мужик, крестьянин"
# ]
#
# "последний": [
# 	"расположенный в конце чего-либо, за всеми остальными"
# 	"самый новый, недавний"
# 	"окончательный, бесповоротный, не обсуждаемый"
# 	"самый плохой, никудышный, отвратительный"
# 	"упомянутый только что, после других"
# ]
#
# "войти": [
# 	"идя, переместиться внутрь чего-либо"
# 	"стать частью, участником чего-либо"
# 	"освоиться с чем-либо, подладиться подо что-то"
# ]
#
# "неделя": [
# 	"единица измерение|измерения время|времени равный|равная семь|семи день|дням от понедельника до воскресенья включительно"
# 	"период время|времени в семь дней, отчисляемый от любого день|дня"
# 	"семидневный промежуток время|времени, посвящённый какому-либо событию, мероприятию и т. п."
# 	"воскресенье"
# ]
#
# "пара": [
# ...

# %%
infile = codecs.open('freqrnc2011.csv', 'r')
freq_dict = pandas.read_csv(infile, sep='\t')
infile.close()
gs_lemmas = list(freq_dict.Lemma[:1150])
gs_poses = list(freq_dict.PoS[:1150])

# %%
gs_lemma_pos = []

for key in GS.keys():
    key = key.encode('utf8')
    index = gs_lemmas.index(key)
    pos = gs_poses[index].upper()
    key += '_' + pos
    gs_lemma_pos.append(key)

# %%
def senses_num(partition):
    clusters = list(set(partition.values()))
    senses_num = len(clusters)
    return senses_num

# %%
start_time = time.time()
#model = Word2Vec.load_word2vec_format('../../Models/web.model.bin', binary=True)
#model = Word2Vec.load_word2vec_format('../../Models/ruscorpora.model.bin', binary=True)
model = Word2Vec.load_word2vec_format('../../Models/news.model.bin', binary=True)
print 'Model loaded successfully. It took ', time.time() - start_time, ' seconds'
# Out:
# Model loaded successfully. It took  10.1487159729  seconds

# %%
def draw_plot(mistakes_pull, topn_range, threshold_range):
    color_list = ['red','blue','green','cyan','pink','orange','grey','yellow','black','purple']
    start = 0
    plt.figure(figsize=(10,10))

    for i in range(len(topn_range)):
        plt.plot(threshold_range, mistakes_pull[ start : start+len(threshold_range) ], \
                 label="topn = " + str(topn_range[i]), linewidth=4, color = color_list[i])
        start += len(threshold_range)

#     plt.title('Average mistake depending on threshold and number of graph nodes (neighbours)', \
#              fontsize=14)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel('Threshold', fontsize=14)
    plt.ylabel('Pearson coefficient', fontsize=14)
    plt.show()

# %% [markdown]
# #### NetworkX and louvain_communities

# %%
topn_range = range(10,55,5) #####################
threshold_range = [(float(k) / 20.0) + 0.05 for k in range(0, 10)] #####################

pearson_coefs_pull = []

for i in topn_range:
    print i
    for j in threshold_range:
        x = [] # output
        y = [] # gs
        for n in range(100): ########################
            word = gs_lemma_pos[n+100].decode('utf8')
            try:
                graph, node, word_clustering = build_rng(word, model, topn=i, threshold=j)
                partition = community.best_partition(graph)
                lemma = word.split('_')[0]
                x.append(senses_num(partition))
                y.append(len(list(set(GS[lemma]))))
            except:
                pass
        pearson_coef = pearsonr(x, y)[0]
        pearson_coefs_pull.append(pearson_coef)
        print '\t', j, '\t', pearson_coef
        if j > 0.5:
            break
# Out:
# 10
# 	0.05 	-0.0607109086779
# 	0.1 	-0.0607109086779
# 	0.15 	-0.0767093242819
# 	0.2 	0.0577336524361
# 	0.25 	0.0537842475094
# 	0.3 	0.079844894498
# 	0.35 	-0.0726133291226
# 	0.4 	-0.164836375092
# 	0.45 	0.14580040929
# 	0.5 	0.255535726392
# 15
# 	0.05 	-0.224982014776
# 	0.1 	-0.224982014776
# 	0.15 	-0.161159750269
# 	0.2 	0.0207767885194
# 	0.25 	0.0526184686212
# 	0.3 	0.0261606043936
# 	0.35 	-0.0887309131831
# 	0.4 	-0.177060524291
# 	0.45 	-0.0293767118957
# 	0.5 	0.00569769660546
# 20
# 	0.05 	-0.0524781088631
# 	0.1 	-0.0524781088631
# 	0.15 	-0.0790695519551
# 	0.2 	-0.0508223813441
# 	0.25 	0.0305226941727
# 	0.3 	-0.0510356388109
# 	0.35 	-0.117219070662
# 	0.4 	-0.212893203325
# 	0.45 	-0.0790195232932
# 	0.5 	0.0984198873421
# 25
# 	0.05 	-0.157208993055
# 	0.1 	-0.157208993055
# 	0.15 	-0.126821945311
# 	0.2 	-0.0139183185561
# 	0.25 	0.0868617989356
# 	0.3 	0.010387227707
# 	0.35 	-0.105943768496
# 	0.4 	-0.194518348777
# 	0.45 	-0.186621723123
# ...

# %%
# pearson_coefs_pull
draw_plot(pearson_coefs_pull, topn_range, threshold_range)

# %% [markdown]
# #### igraph

# %%
topn_range = range(10,55,5)
threshold_range = [(float(k) / 20.0) + 0.05 for k in range(0, 10)]

pearson_coefs_pull = []

for i in topn_range:
    print i
    for j in threshold_range:
        x = [] # output
        y = [] # gs
        for n in range(30): ################ number of words
            word = gs_lemma_pos[n].decode('utf8')
            try:
                graph, node = i_build_rng(word, model, topn=i, threshold=j)
                community = graph.community_leading_eigenvector( weights='weight' ) ###################
                senses_num = len(community)
                lemma = word.split('_')[0]
                x.append(senses_num)
                y.append(len(list(set(GS[lemma]))))
            except:
                pass
        pearson_coef = pearsonr(x, y)[0]
        pearson_coefs_pull.append(pearson_coef)
        print '\t', j, '\t', pearson_coef
        if j > 0.5:
            break
# Out:
# 10
# 	0.05 	-0.138028431485
# 	0.1 	-0.138028431485
# 	0.15 	-0.138028431485
# 	0.2 	-0.138028431485
# 	0.25 	-0.102130927326
# 	0.3 	0.0208474299494
# 	0.35 	-0.235849712559
# 	0.4 	-0.342808305169
# 	0.45 	-0.546033603325
# 	0.5 	-0.271304796136
# 15
# 	0.05 	-0.183632384186
# 	0.1 	-0.183632384186
# 	0.15 	-0.213014897682
# 	0.2 	-0.166937374671
# 	0.25 	-0.0306377763827
# 	0.3 	0.012771171234
# 	0.35 	-0.153302313163
# 	0.4 	-0.234934017313
# 	0.45 	-0.506221683823
# 	0.5 	-0.185791782738
# 20
# 	0.05 	-0.332761954573
# 	0.1 	-0.332761954573
# 	0.15 	-0.332761954573
# 	0.2 	-0.144804141117
# 	0.25 	-0.136406927587
# 	0.3 	-0.00837887136723
# 	0.35 	-0.0142738590054
# 	0.4 	-0.177348129189
# 	0.45 	-0.375031883701
# 	0.5 	-0.0514112075971
# 25
# 	0.05 	-0.173313435526
# 	0.1 	-0.173313435526
# 	0.15 	-0.173313435526
# 	0.2 	-0.262535199077
# 	0.25 	-0.0787288001334
# 	0.3 	0.117333750521
# 	0.35 	0.0234725465103
# 	0.4 	-0.131060518638
# 	0.45 	-0.396085275537
# ...

# %%
# community_leading_eigenvector
draw_plot(pearson_coefs_pull, topn_range, threshold_range)

# %% [markdown]
# # Webcorpora

# %%
model = Word2Vec.load_word2vec_format('../../Models/web.model.bin', binary=True)

# %%
topn_range = range(10,55,5)
threshold_range = [(float(k) / 20.0) + 0.05 for k in range(0, 10)]

pearson_coefs_pull = []

for i in topn_range:
    print i
    for j in threshold_range:
        x = [] # output
        y = [] # gs
        for n in range(30): ################ number of words
            word = gs_lemma_pos[n].decode('utf8')
            try:
                graph, node = i_build_rng(word, model, topn=i, threshold=j)
                community = graph.community_leading_eigenvector( weights='weight' ) ###################
                senses_num = len(community)
                lemma = word.split('_')[0]
                x.append(senses_num)
                y.append(len(list(set(GS[lemma]))))
            except:
                pass
        pearson_coef = pearsonr(x, y)[0]
        pearson_coefs_pull.append(pearson_coef)
        if j > 0.5:
            break
# Out:
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# /Users/nadya/anaconda2/lib/python2.7/site-packages/igraph/__init__.py:1072: RuntimeWarning: ARPACK solver failed to converge (3001 iterations, 0/1 eigenvectors converged) at arpack.c:776
#   membership, _, q = GraphBase.community_leading_eigenvector(self, clusters, **kwds)
# 45
# 50

# %%
# community_leading_eigenvector
draw_plot(pearson_coefs_pull, topn_range, threshold_range)

# %% [markdown]
# # news corpus

# %%
model = Word2Vec.load_word2vec_format('../../Models/news.model.bin', binary=True)

# %%
topn_range = range(10,55,5)
threshold_range = [(float(k) / 20.0) + 0.05 for k in range(0, 10)]

pearson_coefs_pull = []

for i in topn_range:
    print i
    for j in threshold_range:
        x = [] # output
        y = [] # gs
        for n in range(30): ################ number of words
            word = gs_lemma_pos[n].decode('utf8')
            try:
                graph, node = i_build_rng(word, model, topn=i, threshold=j)
                community = graph.community_leading_eigenvector( weights='weight' ) ###################
                senses_num = len(community)
                lemma = word.split('_')[0]
                x.append(senses_num)
                y.append(len(list(set(GS[lemma]))))
            except:
                pass
        pearson_coef = pearsonr(x, y)[0]
        pearson_coefs_pull.append(pearson_coef)
        if j > 0.5:
            break
# Out:
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
# community_leading_eigenvector
draw_plot(pearson_coefs_pull, topn_range, threshold_range)

# %% [markdown]
# # Single-sense classification

# %%
model = Word2Vec.load_word2vec_format('../../Models/ruscorpora.model.bin', binary=True)

# %%
tp = 0.0
fp = 0.0
tn = 0.0
fn = 0.0

for n in range(1000):
    if n % 100 == 0:
        print n
    word = gs_lemma_pos[n].decode('utf8')
    lemma = word.split('_')[0]
    real_sense_number = len(list(set(GS[lemma])))
    try:
        graph, node, word_clustering = build_rng(word, model, topn=20, threshold=0.15)
    except KeyError:
        continue
    partition = community.best_partition(graph)
    induced_sense_number = senses_num(partition)
    if real_sense_number == 1 and induced_sense_number == 1:
        tp += 1.0
    elif real_sense_number > 1 and induced_sense_number > 1:
        tn += 1.0
    elif real_sense_number == 1 and induced_sense_number > 1:
        fn += 1.0
    elif real_sense_number > 1 and induced_sense_number == 1:
        fp += 1.0
        
precision = tp / (tp + fp)
recall = tp / (tp + fn)
f1 = 2 * precision * recall / (precision + recall)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
